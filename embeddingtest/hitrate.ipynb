# %%
from datetime import datetime
from langchain.schema.document import Document
from langchain.vectorstores.chroma import Chroma
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings as STE
from embedding import EmbeddingLoader
import pandas as pd
import re

# %%
#decorator
def checktime(func):
    def wrapper(*args, **kwargs):
        start_time = datetime.now()
        result = func(*args, **kwargs)
        end_time = datetime.now()
        print(f"Function call {func.__name__} took {(end_time - start_time).total_seconds()}s to run.\n")
        return result
    return wrapper

#get model file from .txt file
@checktime
def get_hf_model_names() -> list:
    try:
        with open(file="model/model_list.txt", mode="r", encoding="utf-8") as file:
            model_list = ["model/"+line.strip() for line in file]
    except:
        print("""file not exsist. check directory or file.""")

    return model_list

@checktime
def get_collection_names(model_list:list, if_openai=True) -> list:
    collection_names = [model_name.split("/")[-1] for model_name in model_list]
    if if_openai:
        collection_names.append("text-embedding-ada-002")

    return collection_names

@checktime
def loading_hf_embedding(model_path):
    memorystore = []
    for path in model_path:
        memorystore.append(EmbeddingLoader.SentenceTransformerEmbedding(model_name=path, encode_kwargs={'normalize_embeddings': True}).load())

    return memorystore

# %%
### calling(get model names, collections)
hf_model_path = get_hf_model_names()
collection_names = get_collection_names(hf_model_path)

### loading embedding with hf_model_path
embedding_memorystore = loading_hf_embedding(hf_model_path) #list 저장

### also loading OPENAI Embedding and save
openai_embedding = EmbeddingLoader.OpenAIEmbedding().load() #loading OPENAI Embedding(@text-ada-002) object
embedding_memorystore.append(openai_embedding) #append openai object
# Out:
# Function call get_hf_model_names took 0.00051s to run.
#
# Function call get_collection_names took 0.0s to run.
#
# embedding model in path <model/sentence-transformers/paraphrase-multilingual-mpnet-base-v2> has been loaded successfully.
# Function call load took 3.755441s to run.
#
# embedding model in path <model/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2> has been loaded successfully.
# Function call load took 2.191913s to run.
#
# embedding model in path <model/sentence-transformers/distiluse-base-multilingual-cased-v2> has been loaded successfully.
# Function call load took 1.60226s to run.
#
# embedding model in path <model/sentence-transformers/stsb-xlm-r-multilingual> has been loaded successfully.
# Function call load took 3.754748s to run.
#
# embedding model in path <model/jhgan/ko-sroberta-multitask> has been loaded successfully.
# Function call load took 1.970871s to run.
#
# embedding model in path <model/snunlp/KR-SBERT-V40K-klueNLI-augSTS> has been loaded successfully.
# Function call load took 2.085722s to run.
#
# embedding model in path <model/bongsoo/moco-sentencedistilbertV2.1> has been loaded successfully.
# Function call load took 2.865791s to run.
#
# embedding model in path <model/bongsoo/kpf-sbert-128d-v1> has been loaded successfully.
# Function call load took 2.183454s to run.
#
# embedding model in path <model/M-CLIP/M-BERT-Distil-40> has been loaded successfully.
# Function call load took 2.534906s to run.
#
# embedding model in path <model/google/canine-c> has been loaded successfully.
# Function call load took 3.063429s to run.
#
# embedding model in path <model/smartmind/roberta-ko-small-tsdae> has been loaded successfully.
# Function call load took 0.687981s to run.
#
# embedding model in path <model/BM-K/KoSimCSE-roberta-multitask> has been loaded successfully.
# Function call load took 2.215515s to run.
#
# Function call loading_hf_embedding took 28.912031s to run.
#
# OpenAI Embedding has been activated.
# Function call load took 0.0s to run.

# %%
# 12 hf embeddings + openai embedding(@text-ada-002)
print(len(embedding_memorystore))
#check collection names before launch
print(collection_names)
# Out:
# 13
# ['paraphrase-multilingual-mpnet-base-v2', 'paraphrase-multilingual-MiniLM-L12-v2', 'distiluse-base-multilingual-cased-v2', 'stsb-xlm-r-multilingual', 'ko-sroberta-multitask', 'KR-SBERT-V40K-klueNLI-augSTS', 'moco-sentencedistilbertV2.1', 'kpf-sbert-128d-v1', 'M-BERT-Distil-40', 'canine-c', 'roberta-ko-small-tsdae', 'KoSimCSE-roberta-multitask', 'text-embedding-ada-002']

# %%
def _ab_getter(collection_name:str)->list:
    "get embedding list and add collection names"
    footer = ["-a", "-b"]
    return [collection_name+footer_string for footer_string in footer]

def _strip_replace_text(s: str)->str:
    "regex"
    regex = '([^가-힣0-9a-zA-Z])'
    s = re.sub(pattern=regex, repl="", string=s)
    return s

# %%
## check regexed document name
# for check in hitrate_doc:
#     print(_strip_replace_text(check))

# %% [markdown]
# #### 여기에서부터 QA query로 넣어서 hitrate 평가(hitrate_test_qa.csv)
# - k 개수에 따라서 (@1, @3, @5, @10) hitrate 평가 후 csv file로 저장

# %%
## wrapper 함수들 ->

def get_hitrate(embedding_function, collection_list:list, k:int, hitrate_csv:pd.DataFrame, result_df:pd.DataFrame) -> pd.DataFrame:
    hitrate_q = hitrate_csv["Question"]
    hitrate_doc = hitrate_csv["Documents"] 

    for collection_name_complete in collection_list:
        hit = 0
    
        db = Chroma(persist_directory="chroma", collection_name=collection_name_complete, embedding_function=embedding_function)
        print(f"with document set <Team {collection_name_complete[-1].upper()}>: {db._collection.name}, {db._collection.count()}, with k={k}")

        for hitq, hitdoc in zip(hitrate_q, hitrate_doc):
            search_result = db.similarity_search(query=hitq, k=k)

            if search_result_rating(search_result, answer_document=hitdoc):
                print(f"question <{hitq}> hit!")
                hit += 1

        result_df.loc[f'@{k}', collection_name_complete] = (hit/len(hitrate_q))*100
        print((hit/len(hitrate_q))*100)

        ### result sep
        print("="*80,"\n")

    return result_df

def search_result_rating(search_result:Document, answer_document:str)->bool:
    """
        Set flag and check if it meets answer_document.
        Args: 
            search_result: search result. Langchain Document object.
            answer_document:
    """
    answer_parsed = _strip_replace_text(answer_document)
    for document in search_result:
        parsed_title = _strip_replace_text(document.metadata["title"])
    
        if parsed_title == answer_parsed:
            return True

    return False

# %%
### main
## hit rate test csv load
hitrate_csv = pd.read_csv("hitrate_test_qa.csv", encoding='utf-8')
result_df = pd.DataFrame()

for embedding_function, collection_name in zip(embedding_memorystore, collection_names):
    ab_names = _ab_getter(collection_name=collection_name)

    for knum in [1,3,5,10]:
        result_df = get_hitrate(embedding_function=embedding_function, collection_list=ab_names, k=knum, hitrate_csv=hitrate_csv, result_df=result_df)

result_df.to_csv("hitrate_result.csv", encoding="utf-8")
# Out:
# with document set <Team A>: paraphrase-multilingual-mpnet-base-v2-a, 1782, with k=1
# question <우리 집이 최근 화재로 인해 살 곳을 잃었어요. 긴급하게 지원받을 수 있는 방법이 있을까요?> hit!
# question <제가 저소득층인데, 쌀 지원을 위한 프로그램 신청은 어떻게 하나요?> hit!
# question <집안의 낡은 전구를 에너지 효율이 좋은 램프로 교체하고 싶어요. 지원을 받으려면 어디로 연락해야 하나요?> hit!
# question <최근 직장을 그만두었는데, 건강보험을 계속해서 유지하고 싶어요. 어떤 제도를 활용할 수 있을까요?> hit!
# question <고용보험에 18개월간 가입했지만, 총 근무일수가 180일이 안 되는데 실업급여를 신청할 수 있나요?> hit!
# question <범죄 경력이 있는 20살 청년이 취업을 희망할 때 이용할 수 있는 프로그램은 무엇인가요?> hit!
# question <제가 고용보험에 가입하지 않았는데, 출산 후 지원을 받고 싶어요. 어디로 문의해야 하나요?> hit!
# question <임신 중에 어떤 예방접종을 해야 하는지 알고 싶습니다. 정보를 어디서 찾을 수 있나요?> hit!
# question <조산이나 저체중으로 태어난 아기가 병원 치료를 받을 때 부모님의 부담금 비율은 어떻게 되나요?> hit!
# question <만 1세 된 아이를 어린이집에 보내지 않고 가정에서 양육할 때 부모가 받을 수 있는 현금 지원은 어떻게 되나요?> hit!
# question <열 살짜리 아이가 입원을 해서 병원비를 내야 하는데, 어떤 부분에 대해 지원을 받을 수 있나요?> hit!
# question <만 19세인데 학교를 다니지 않아요. 건강검진을 받을 수 있나요?> hit!
# question <위기상황에 처한 청소년이 안전의 위협을 받을때 어디로 연락해야할까요?> hit!
# question <고등학교 1학년 학생이 폰 없이는 못 사는 것 같아 걱정이에요. 무슨 조치를 취할 수 있을까요?> hit!
# question <대체복무요원으로 일하고 있는데 가정에 긴급한 경제적 문제가 생겼어요. 이럴 때 병역을 감면받을 수 있나요?> hit!
# question <대학생인데, 지금 당장 학비를 마련할 수 없어요. 나중에 직업을 가진 뒤에 돈을 갚을 수 있는 대출이 있다면 알려주세요.> hit!
# question <도박 중독으로 고민하는 친구에게 어떻게 도움을 줄 수 있을까요?> hit!
# question <제 어머님이 최근 노인장기요양보험 수급자가 되셨는데요, 어느 정도의 소득 수준이면 본인부담금을 줄일 수 있나요?> hit!
# question <치매를 앓고 계신 아버지가 있어요. 장기요양인정 신청은 언제부터 가능한가요?> hit!
# question <곧 있을 퇴직 후 생활에 대비하여 금융상품을 알아보고 싶은데 어디서 정보를 얻을 수 있을까요?> hit!
# question <노인 분들이 문화생활을 즐길 수 있는 공간으로, 어떤 시설이 있는지 궁금해요.> hit!
# question <인터넷 사용이 어려운 부모님께 노후 준비 상담을 받게 하고 싶어요. 어떻게 안내해야 하나요?> hit!
# question <할머니가 백내장 수술이 필요한데 지방자치단체에서 지원하는 프로그램이 있나요?> hit!
# question <65세 이상인데 치아가 몇 개 빠진 경우에도 임플란트 지원을 받을 수 있나요?> hit!
# question <대학 캠퍼스 안에서 장애 학생을 위한 편의를 제공받고 싶어요. 누구에게 연락해야 하나요?> hit!
# question <현재 자폐 스펙트럼을 가진 4살짜리 아이의 엄마인데요, 상담을 위해 필요한 서류는 무엇인가요?> hit!
# question <여자 장애인을 위한 청소 도움을 요청하려면 어떻게 해야 하나요?> hit!
# question <주택을 소유하지 않은 장애인 가구원을 위한 특별공급 주택이 있다고 들었어요. 자격 요건에는 어떤 것들이 있나요?> hit!
# question <신체 장애를 가진 아이의 신체 기능을 회복하기 위한 스포츠 활동은 어디에서 지원받을 수 있나요?> hit!
# question <아버지가 국가유공자이신데, 제가 우울증 치료를 위해 받을 수 있는 지원 서비스가 있을까요?> hit!
# question <우리 아버지가 전쟁에 참가하셨고 지금 심리적 방황을 겪고 계셔요. 어디에서 도움을 요청할 수 있을까요?> hit!
# question <10년 복무 후 전역한 군인 출신인데, 독립적으로 사업을 시작했습니다. 이 경우 받을 수 있는 지원금이 있나요?> hit!
# question <저희 아버지께서 국가유공상이자로 6급 판정을 받으셨어요. 시내버스를 비롯한 대중교통을 이용할 때 혜택이 있나요?> hit!
# question <제가 비정규직으로 일하고 있는데, 생계 유지가 힘들어지고 있어요. 긴급하게 돈을 빌릴 수 있는 복지 제도가 있을까요?> hit!
# question <건물 임대 관련해서 갈등을 겪고 있어요. 어디로 문의해야 하나요?> hit!
# question <제가 최근에 음식점을 차려서 자영업을 시작했는데, 사업이 잘 됐으면 좋겠어요. 어떻게 도움을 받을 수 있을까요?> hit!
# question <나는 어업에 종사하고 있고, 앞으로 몇 년간의 수입을 안정적으로 모으고 싶어요. 이런 계획에 맞는 금융 서비스가 있을까요?> hit!
# question <섬에 살아서 배를 자주 이용해야 하는데, 요금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <북한에서 온 내 친구가 대학교 교육비를 지원받고 싶어하는데 어떻게 신청할 수 있나요?> hit!
# question <회사에서 다쳐서 일을 못하게 되었어요. 다시 일할 수 있게 도와주는 곳이 어디인가요?> hit!
# question <출소한 이후에도 사회에 잘 적응하고 독립적인 생활을 할 수 있도록 어떤 프로그램이 마련되어 있나요?> hit!
# question <아빠 없이 아이를 키우고 있는데, 양육비 지원은 어떻게 신청하나요?> hit!
#
있나요?> hit!
# question <저희 집 벽이 슬레이트인데, 환경적으로 문제가 있어서 갈아내고 싶어요. 이런 경우 어떤 도움을 받을 수 있나요?> hit!
# question <집안의 낡은 전구를 에너지 효율이 좋은 램프로 교체하고 싶어요. 지원을 받으려면 어디로 연락해야 하나요?> hit!
# question <불완전한 주거환경에서 아이와 생활하고 있는 가정은 어떠한 지원을 받을 수 있나요?> hit!
# question <최근 직장을 그만두었는데, 건강보험을 계속해서 유지하고 싶어요. 어떤 제도를 활용할 수 있을까요?> hit!
# question <제가 듣고 있는 일반고 직업교육 과정이 6개월 이상인데, 졸업 후 중견기업에 취업하면 돈을 받을 수 있나요?> hit!
# question <고용보험에 18개월간 가입했지만, 총 근무일수가 180일이 안 되는데 실업급여를 신청할 수 있나요?> hit!
# question <AI나 빅데이터 기술을 배워 직업 훈련을 받으려고 하는데, 어떤 과정들이 제공되나요?> hit!
# question <범죄 경력이 있는 20살 청년이 취업을 희망할 때 이용할 수 있는 프로그램은 무엇인가요?> hit!
# question <제가 고용보험에 가입하지 않았는데, 출산 후 지원을 받고 싶어요. 어디로 문의해야 하나요?> hit!
# question <임신 중에 어떤 예방접종을 해야 하는지 알고 싶습니다. 정보를 어디서 찾을 수 있나요?> hit!
# question <조산이나 저체중으로 태어난 아기가 병원 치료를 받을 때 부모님의 부담금 비율은 어떻게 되나요?> hit!
# question <만 1세 된 아이를 어린이집에 보내지 않고 가정에서 양육할 때 부모가 받을 수 있는 현금 지원은 어떻게 되나요?> hit!
# question <저소득층 가정에 아이가 있는데 기저귀 구입비용 지원을 받고 싶어요. 어디에서 어떻게 지원을 받을 수 있나요?> hit!
# question <제가 밤늦게까지 일을 하는데, 아이를 늦은 시간까지 어린이집에 맡길 수 있을까요?> hit!
# question <열 살짜리 아이가 입원을 해서 병원비를 내야 하는데, 어떤 부분에 대해 지원을 받을 수 있나요?> hit!
# question <제가 집에서 아이를 낳게 되면 그에 대한 어떤 혜택을 받을 수 있나요?> hit!
# question <만 19세인데 학교를 다니지 않아요. 건강검진을 받을 수 있나요?> hit!
# question <위기상황에 처한 청소년이 안전의 위협을 받을때 어디로 연락해야할까요?> hit!
# question <고등학교 1학년 학생이 폰 없이는 못 사는 것 같아 걱정이에요. 무슨 조치를 취할 수 있을까요?> hit!
# question <대학생인데, 지금 당장 학비를 마련할 수 없어요. 나중에 직업을 가진 뒤에 돈을 갚을 수 있는 대출이 있다면 알려주세요.> hit!
# question <저는 미술에 재능이 있는 학생입니다. 장학금 지원을 받고 싶은데 어떻게 해야 하죠?> hit!
# question <아이가 암 진단을 받았는데, 의료비 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건강보험 가입자가 중증치매로 인정받을 경우 어떤 혜택을 받을 수 있나요?> hit!
# question <도박 중독으로 고민하는 친구에게 어떻게 도움을 줄 수 있을까요?> hit!
# question <치매를 앓고 계신 아버지가 있어요. 장기요양인정 신청은 언제부터 가능한가요?> hit!
# question <사랑하는 사람이 자살 위험 징후를 보이고 있는데, 어떻게 도움을 줄 수 있을까요?> hit!
# question <노인 분들이 문화생활을 즐길 수 있는 공간으로, 어떤 시설이 있는지 궁금해요.> hit!
# question <조부모님이 혼자 계시면서 필요한 생활 서비스를 찾고 계신데 어떻게 안내해드려야 할까요?> hit!
# question <58세이고 7억짜리 집이 있는데, 이 집으로 연금을 받고 싶어. 어떤 제도를 이용할 수 있을까?> hit!
# question <65세 이상인데 치아가 몇 개 빠진 경우에도 임플란트 지원을 받을 수 있나요?> hit!
# question <노년층의 사회 참여를 위한 프로그램에 참여하고 싶어요. 어디에서 신청할 수 있나요?> hit!
# question <대학 캠퍼스 안에서 장애 학생을 위한 편의를 제공받고 싶어요. 누구에게 연락해야 하나요?> hit!
# question <변호사 비용을 지불할 능력이 안 되는데, 어떻게 법적 문제를 해결할 수 있을까요?> hit!
# question <여자 장애인을 위한 청소 도움을 요청하려면 어떻게 해야 하나요?> hit!
# question <주택을 소유하지 않은 장애인 가구원을 위한 특별공급 주택이 있다고 들었어요. 자격 요건에는 어떤 것들이 있나요?> hit!
# question <신체 장애를 가진 아이의 신체 기능을 회복하기 위한 스포츠 활동은 어디에서 지원받을 수 있나요?> hit!
# question <군대에서 오랫동안 복무하고 나왔는데 법적인 조언이 필요해요. 어디로 연락해야 하죠?> hit!
# question <아버지가 국가유공자이신데, 제가 우울증 치료를 위해 받을 수 있는 지원 서비스가 있을까요?> hit!
# question <저희 아버지께서는 순직하신 유공자예요. 제가 대학원 입학할 때 받을 수 있는 장학금이 있나요?> hit!
# question <10년 복무 후 전역한 군인 출신인데, 독립적으로 사업을 시작했습니다. 이 경우 받을 수 있는 지원금이 있나요?> hit!
# question <저희 아버지께서 국가유공상이자로 6급 판정을 받으셨어요. 시내버스를 비롯한 대중교통을 이용할 때 혜택이 있나요?> hit!
# question <제가 비정규직으로 일하고 있는데, 생계 유지가 힘들어지고 있어요. 긴급하게 돈을 빌릴 수 있는 복지 제도가 있을까요?> hit!
# question <신용이 낮아서 대출을 받기 어려운데, 저에게 맞는 대출 서비스가 있나요? 어디에 상담을 요청해야 하나요?> hit!
# question <작은 가게를 운영하는데, 자금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건물 임대 관련해서 갈등을 겪고 있어요. 어디로 문의해야 하나요?> hit!
# question <제가 최근에 음식점을 차려서 자영업을 시작했는데, 사업이 잘 됐으면 좋겠어요. 어떻게 도움을 받을 수 있을까요?> hit!
# question <섬에 살아서 배를 자주 이용해야 하는데, 요금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <북한에서 온 내 친구가 대학교 교육비를 지원받고 싶어하는데 어떻게 신청할 수 있나요?> hit!
# question <회사에서 다쳐서 일을 못하게 되었어요. 다시 일할 수 있게 도와주는 곳이 어디인가요?> hit!
# question <출소한 이후에도 사회에 잘 적응하고 독립적인 생활을 할 수 있도록 어떤 프로그램이 마련되어 있나요?> hit!
# question <아빠 없이 아이를 키우고 있는데, 양육비 지원은 어떻게 신청하나요?> hit!
# 51.42857142857142
# ================================================================================
#
# with document set <Team B>: paraphrase-multilingual-MiniLM-L12-v2-b, 1307, with k=5
# question <가스 안전장치를 설치하고자 하는데 정부 지원은 어떻게 받을 수 있나요?> hit!
# question <저희 집 벽이 슬레이트인데, 환경적으로 문제가 있어서 갈아내고 싶어요. 이런 경우 어떤 도움을 받을 수 있나요?> hit!
# question <제가 저소득층인데, 쌀 지원을 위한 프로그램 신청은 어떻게 하나요?> hit!
# question <집안의 낡은 전구를 에너지 효율이 좋은 램프로 교체하고 싶어요. 지원을 받으려면 어디로 연락해야 하나요?> hit!
# ...
#
# with document set <Team A>: text-embedding-ada-002-a, 929, with k=5
# question <가스 안전장치를 설치하고자 하는데 정부 지원은 어떻게 받을 수 있나요?> hit!
# question <제가 간병인을 집으로 부를 수 있게 해주는 서비스는 어디에서 신청할 수 있나요?> hit!
# question <우리 집이 최근 화재로 인해 살 곳을 잃었어요. 긴급하게 지원받을 수 있는 방법이 있을까요?> hit!
# question <저희 어머니가 사시는 임대 아파트가 오래되어 수리가 필요한데, 이런 상황에서 도움받을 수 있는 방법이 있나요?> hit!
# question <아이가 축구학원에 다니고 싶어 하는데, 우리는 기초생활수급 가정이에요. 지원받을 수 있는 방법이 있나요?> hit!
# question <저희 집 벽이 슬레이트인데, 환경적으로 문제가 있어서 갈아내고 싶어요. 이런 경우 어떤 도움을 받을 수 있나요?> hit!
# question <집안의 낡은 전구를 에너지 효율이 좋은 램프로 교체하고 싶어요. 지원을 받으려면 어디로 연락해야 하나요?> hit!
# question <최근 직장을 그만두었는데, 건강보험을 계속해서 유지하고 싶어요. 어떤 제도를 활용할 수 있을까요?> hit!
# question <제가 듣고 있는 일반고 직업교육 과정이 6개월 이상인데, 졸업 후 중견기업에 취업하면 돈을 받을 수 있나요?> hit!
# question <고용보험에 18개월간 가입했지만, 총 근무일수가 180일이 안 되는데 실업급여를 신청할 수 있나요?> hit!
# question <제가 회사와 학교를 병행하며 배울 수 있는 제도에 대해 알아보고 싶어요. 어느 기관에 연락해야 하나요?> hit!
# question <나는 40대 중반에 창업을 계획하고 있어요. 창업 지원과 관련하여 어디에 문의해야 하나요?> hit!
# question <AI나 빅데이터 기술을 배워 직업 훈련을 받으려고 하는데, 어떤 과정들이 제공되나요?> hit!
# question <청년을 채용한 후, 6개월이 지나지 않았는데, 장려금 신청이 가능한가요?> hit!
# question <범죄 경력이 있는 20살 청년이 취업을 희망할 때 이용할 수 있는 프로그램은 무엇인가요?> hit!
# question <졸업 직전인 직업계고 3학년 학생으로서 현장실습에 참여할 예정인데, 어떤 추가적인 혜택을 기대할 수 있나요?> hit!
# question <제가 고용보험에 가입하지 않았는데, 출산 후 지원을 받고 싶어요. 어디로 문의해야 하나요?> hit!
# question <조산이나 저체중으로 태어난 아기가 병원 치료를 받을 때 부모님의 부담금 비율은 어떻게 되나요?> hit!
# question <만 1세 된 아이를 어린이집에 보내지 않고 가정에서 양육할 때 부모가 받을 수 있는 현금 지원은 어떻게 되나요?> hit!
# question <저소득층 가정에 아이가 있는데 기저귀 구입비용 지원을 받고 싶어요. 어디에서 어떻게 지원을 받을 수 있나요?> hit!
# question <제가 밤늦게까지 일을 하는데, 아이를 늦은 시간까지 어린이집에 맡길 수 있을까요?> hit!
# question <열 살짜리 아이가 입원을 해서 병원비를 내야 하는데, 어떤 부분에 대해 지원을 받을 수 있나요?> hit!
# question <제가 운영 중인 청소년 단체의 활동을 확장하고자 하는데, 지원 받을 수 있는 기관을 알려주세요.> hit!
# question <제가 대학교 학부 철학과 1학년인데 장학금을 신청할 수 있나요?> hit!
# question <만 19세인데 학교를 다니지 않아요. 건강검진을 받을 수 있나요?> hit!
# question <위기상황에 처한 청소년이 안전의 위협을 받을때 어디로 연락해야할까요?> hit!
# question <대체복무요원으로 일하고 있는데 가정에 긴급한 경제적 문제가 생겼어요. 이럴 때 병역을 감면받을 수 있나요?> hit!
# question <대학생인데, 지금 당장 학비를 마련할 수 없어요. 나중에 직업을 가진 뒤에 돈을 갚을 수 있는 대출이 있다면 알려주세요.> hit!
# question <저는 미술에 재능이 있는 학생입니다. 장학금 지원을 받고 싶은데 어떻게 해야 하죠?> hit!
# question <아이가 암 진단을 받았는데, 의료비 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <도박 중독으로 고민하는 친구에게 어떻게 도움을 줄 수 있을까요?> hit!
# question <제 어머님이 최근 노인장기요양보험 수급자가 되셨는데요, 어느 정도의 소득 수준이면 본인부담금을 줄일 수 있나요?> hit!
# question <사랑하는 사람이 자살 위험 징후를 보이고 있는데, 어떻게 도움을 줄 수 있을까요?> hit!
# question <곧 있을 퇴직 후 생활에 대비하여 금융상품을 알아보고 싶은데 어디서 정보를 얻을 수 있을까요?> hit!
# question <노인 분들이 문화생활을 즐길 수 있는 공간으로, 어떤 시설이 있는지 궁금해요.> hit!
# question <퇴직 후 급하게 돈이 필요해진 경우, 연금을 받고 있다면 어떠한 정부 지원 프로그램에 참여할 수 있을까요?> hit!
# question <58세이고 7억짜리 집이 있는데, 이 집으로 연금을 받고 싶어. 어떤 제도를 이용할 수 있을까?> hit!
# question <65세 이상인데 치아가 몇 개 빠진 경우에도 임플란트 지원을 받을 수 있나요?> hit!
# question <노년층의 사회 참여를 위한 프로그램에 참여하고 싶어요. 어디에서 신청할 수 있나요?> hit!
# question <제 아이는 청각 장애가 있어 특별한 교육이 필요한데, 특수학급에 참여하려면 어떤 준비를 해야 할까요?> hit!
# question <대학 캠퍼스 안에서 장애 학생을 위한 편의를 제공받고 싶어요. 누구에게 연락해야 하나요?> hit!
# question <현재 자폐 스펙트럼을 가진 4살짜리 아이의 엄마인데요, 상담을 위해 필요한 서류는 무엇인가요?> hit!
# question <우리 회사는 지난달에 중증장애인 2명을 채용했어요. 작업지도에 조언을 해줄 전문 작업지도원도 고용했는데, 국가로부터 어떤 도움을 받을 수 있나요?> hit!
# question <주택을 소유하지 않은 장애인 가구원을 위한 특별공급 주택이 있다고 들었어요. 자격 요건에는 어떤 것들이 있나요?> hit!
# question <신체 장애를 가진 아이의 신체 기능을 회복하기 위한 스포츠 활동은 어디에서 지원받을 수 있나요?> hit!
# question <우리 아버지가 전쟁에 참가하셨고 지금 심리적 방황을 겪고 계셔요. 어디에서 도움을 요청할 수 있을까요?> hit!
# question <저희 할머니께서 독립운동을 하신 유공자셨는데, 혹시 저도 지원을 받을 수 있나요?> hit!
# question <태풍으로 인해 큰 피해를 입었습니다. 정부로부터 보상을 받으려면 어떤 절차를 거쳐야 하나요?> hit!
# question <10년 복무 후 전역한 군인 출신인데, 독립적으로 사업을 시작했습니다. 이 경우 받을 수 있는 지원금이 있나요?> hit!
# question <회사가 경영난으로 인해 문을 닫게 되면서 경제적으로 어려움을 겪고 있어요. 정부 지원금을 어떻게 신청할 수 있나요?> hit!
# question <신용이 낮아서 대출을 받기 어려운데, 저에게 맞는 대출 서비스가 있나요? 어디에 상담을 요청해야 하나요?> hit!
# question <작은 가게를 운영하는데, 자금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건물 임대 관련해서 갈등을 겪고 있어요. 어디로 문의해야 하나요?> hit!
# question <세금 문제를 무료로 상담해 줄 수 있는 곳을 알려주세요.> hit!
# question <혼자 사는 사람들을 위한 친목 모임이나 네트워크 지원이 있는지 궁금해요.> hit!
# question <나는 어업에 종사하고 있고, 앞으로 몇 년간의 수입을 안정적으로 모으고 싶어요. 이런 계획에 맞는 금융 서비스가 있을까요?> hit!
# question <섬에 살아서 배를 자주 이용해야 하는데, 요금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <북한에서 온 내 친구가 대학교 교육비를 지원받고 싶어하는데 어떻게 신청할 수 있나요?> hit!
# question <내 외국인 친구가 건강 문제로 병원을 찾아야 하는 상황인데, 어떤 기관에서 정보를 얻을 수 있나요?> hit!
# question <아빠 없이 아이를 키우고 있는데, 양육비 지원은 어떻게 신청하나요?> hit!
# 57.14285714285714
# ================================================================================
#
# with document set <Team B>: text-embedding-ada-002-b, 928, with k=5
# question <가스 안전장치를 설치하고자 하는데 정부 지원은 어떻게 받을 수 있나요?> hit!
# question <제가 간병인을 집으로 부를 수 있게 해주는 서비스는 어디에서 신청할 수 있나요?> hit!
# question <우리 집이 최근 화재로 인해 살 곳을 잃었어요. 긴급하게 지원받을 수 있는 방법이 있을까요?> hit!
# question <아이가 축구학원에 다니고 싶어 하는데, 우리는 기초생활수급 가정이에요. 지원받을 수 있는 방법이 있나요?> hit!
# question <저희 집 벽이 슬레이트인데, 환경적으로 문제가 있어서 갈아내고 싶어요. 이런 경우 어떤 도움을 받을 수 있나요?> hit!
# question <집안의 낡은 전구를 에너지 효율이 좋은 램프로 교체하고 싶어요. 지원을 받으려면 어디로 연락해야 하나요?> hit!
# question <최근 직장을 그만두었는데, 건강보험을 계속해서 유지하고 싶어요. 어떤 제도를 활용할 수 있을까요?> hit!
# question <제가 듣고 있는 일반고 직업교육 과정이 6개월 이상인데, 졸업 후 중견기업에 취업하면 돈을 받을 수 있나요?> hit!
# question <고용보험에 18개월간 가입했지만, 총 근무일수가 180일이 안 되는데 실업급여를 신청할 수 있나요?> hit!
# question <제가 회사와 학교를 병행하며 배울 수 있는 제도에 대해 알아보고 싶어요. 어느 기관에 연락해야 하나요?> hit!
# question <나는 40대 중반에 창업을 계획하고 있어요. 창업 지원과 관련하여 어디에 문의해야 하나요?> hit!
# question <AI나 빅데이터 기술을 배워 직업 훈련을 받으려고 하는데, 어떤 과정들이 제공되나요?> hit!
# question <청년을 채용한 후, 6개월이 지나지 않았는데, 장려금 신청이 가능한가요?> hit!
# question <범죄 경력이 있는 20살 청년이 취업을 희망할 때 이용할 수 있는 프로그램은 무엇인가요?> hit!
# question <졸업 직전인 직업계고 3학년 학생으로서 현장실습에 참여할 예정인데, 어떤 추가적인 혜택을 기대할 수 있나요?> hit!
# question <제가 고용보험에 가입하지 않았는데, 출산 후 지원을 받고 싶어요. 어디로 문의해야 하나요?> hit!
# question <조산이나 저체중으로 태어난 아기가 병원 치료를 받을 때 부모님의 부담금 비율은 어떻게 되나요?> hit!
# question <만 1세 된 아이를 어린이집에 보내지 않고 가정에서 양육할 때 부모가 받을 수 있는 현금 지원은 어떻게 되나요?> hit!
# question <열 살짜리 아이가 입원을 해서 병원비를 내야 하는데, 어떤 부분에 대해 지원을 받을 수 있나요?> hit!
# question <제가 운영 중인 청소년 단체의 활동을 확장하고자 하는데, 지원 받을 수 있는 기관을 알려주세요.> hit!
# question <만 19세인데 학교를 다니지 않아요. 건강검진을 받을 수 있나요?> hit!
# question <위기상황에 처한 청소년이 안전의 위협을 받을때 어디로 연락해야할까요?> hit!
# question <대학생인데, 지금 당장 학비를 마련할 수 없어요. 나중에 직업을 가진 뒤에 돈을 갚을 수 있는 대출이 있다면 알려주세요.> hit!
# question <아이가 암 진단을 받았는데, 의료비 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건강보험 가입자가 중증치매로 인정받을 경우 어떤 혜택을 받을 수 있나요?> hit!
# question <도박 중독으로 고민하는 친구에게 어떻게 도움을 줄 수 있을까요?> hit!
# question <제 어머님이 최근 노인장기요양보험 수급자가 되셨는데요, 어느 정도의 소득 수준이면 본인부담금을 줄일 수 있나요?> hit!
# question <사랑하는 사람이 자살 위험 징후를 보이고 있는데, 어떻게 도움을 줄 수 있을까요?> hit!
# question <노인 분들이 문화생활을 즐길 수 있는 공간으로, 어떤 시설이 있는지 궁금해요.> hit!
# question <58세이고 7억짜리 집이 있는데, 이 집으로 연금을 받고 싶어. 어떤 제도를 이용할 수 있을까?> hit!
# question <65세 이상인데 치아가 몇 개 빠진 경우에도 임플란트 지원을 받을 수 있나요?> hit!
# question <노년층의 사회 참여를 위한 프로그램에 참여하고 싶어요. 어디에서 신청할 수 있나요?> hit!
# question <제 아이는 청각 장애가 있어 특별한 교육이 필요한데, 특수학급에 참여하려면 어떤 준비를 해야 할까요?> hit!
# question <대학 캠퍼스 안에서 장애 학생을 위한 편의를 제공받고 싶어요. 누구에게 연락해야 하나요?> hit!
# question <현재 자폐 스펙트럼을 가진 4살짜리 아이의 엄마인데요, 상담을 위해 필요한 서류는 무엇인가요?> hit!
# question <여자 장애인을 위한 청소 도움을 요청하려면 어떻게 해야 하나요?> hit!
# question <우리 회사는 지난달에 중증장애인 2명을 채용했어요. 작업지도에 조언을 해줄 전문 작업지도원도 고용했는데, 국가로부터 어떤 도움을 받을 수 있나요?> hit!
# question <주택을 소유하지 않은 장애인 가구원을 위한 특별공급 주택이 있다고 들었어요. 자격 요건에는 어떤 것들이 있나요?> hit!
# question <신체 장애를 가진 아이의 신체 기능을 회복하기 위한 스포츠 활동은 어디에서 지원받을 수 있나요?> hit!
# question <우리 아버지가 전쟁에 참가하셨고 지금 심리적 방황을 겪고 계셔요. 어디에서 도움을 요청할 수 있을까요?> hit!
# question <태풍으로 인해 큰 피해를 입었습니다. 정부로부터 보상을 받으려면 어떤 절차를 거쳐야 하나요?> hit!
# question <10년 복무 후 전역한 군인 출신인데, 독립적으로 사업을 시작했습니다. 이 경우 받을 수 있는 지원금이 있나요?> hit!
# question <저희 아버지께서 국가유공상이자로 6급 판정을 받으셨어요. 시내버스를 비롯한 대중교통을 이용할 때 혜택이 있나요?> hit!
# question <신용이 낮아서 대출을 받기 어려운데, 저에게 맞는 대출 서비스가 있나요? 어디에 상담을 요청해야 하나요?> hit!
# question <작은 가게를 운영하는데, 자금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건물 임대 관련해서 갈등을 겪고 있어요. 어디로 문의해야 하나요?> hit!
# question <혼자 사는 사람들을 위한 친목 모임이나 네트워크 지원이 있는지 궁금해요.> hit!
# question <북한에서 온 내 친구가 대학교 교육비를 지원받고 싶어하는데 어떻게 신청할 수 있나요?> hit!
# question <농사일이 바빠서 혼자서 다 하기 힘든데, 정부에서 도와줄 수 있는 프로그램이 있나요?> hit!
# question <아빠 없이 아이를 키우고 있는데, 양육비 지원은 어떻게 신청하나요?> hit!
# 47.61904761904761
# ================================================================================
#
# with document set <Team A>: text-embedding-ada-002-a, 929, with k=10
# question <가스 안전장치를 설치하고자 하는데 정부 지원은 어떻게 받을 수 있나요?> hit!
# question <제가 간병인을 집으로 부를 수 있게 해주는 서비스는 어디에서 신청할 수 있나요?> hit!
# question <우리 집이 최근 화재로 인해 살 곳을 잃었어요. 긴급하게 지원받을 수 있는 방법이 있을까요?> hit!
# question <저희 어머니가 사시는 임대 아파트가 오래되어 수리가 필요한데, 이런 상황에서 도움받을 수 있는 방법이 있나요?> hit!
# question <아이가 축구학원에 다니고 싶어 하는데, 우리는 기초생활수급 가정이에요. 지원받을 수 있는 방법이 있나요?> hit!
# question <저희 집 벽이 슬레이트인데, 환경적으로 문제가 있어서 갈아내고 싶어요. 이런 경우 어떤 도움을 받을 수 있나요?> hit!
# question <집안의 낡은 전구를 에너지 효율이 좋은 램프로 교체하고 싶어요. 지원을 받으려면 어디로 연락해야 하나요?> hit!
# question <최근 직장을 그만두었는데, 건강보험을 계속해서 유지하고 싶어요. 어떤 제도를 활용할 수 있을까요?> hit!
# question <제가 듣고 있는 일반고 직업교육 과정이 6개월 이상인데, 졸업 후 중견기업에 취업하면 돈을 받을 수 있나요?> hit!
# question <고용보험에 18개월간 가입했지만, 총 근무일수가 180일이 안 되는데 실업급여를 신청할 수 있나요?> hit!
# question <제가 회사와 학교를 병행하며 배울 수 있는 제도에 대해 알아보고 싶어요. 어느 기관에 연락해야 하나요?> hit!
# question <나는 40대 중반에 창업을 계획하고 있어요. 창업 지원과 관련하여 어디에 문의해야 하나요?> hit!
# question <AI나 빅데이터 기술을 배워 직업 훈련을 받으려고 하는데, 어떤 과정들이 제공되나요?> hit!
# question <청년을 채용한 후, 6개월이 지나지 않았는데, 장려금 신청이 가능한가요?> hit!
# question <범죄 경력이 있는 20살 청년이 취업을 희망할 때 이용할 수 있는 프로그램은 무엇인가요?> hit!
# question <졸업 직전인 직업계고 3학년 학생으로서 현장실습에 참여할 예정인데, 어떤 추가적인 혜택을 기대할 수 있나요?> hit!
# question <제가 고용보험에 가입하지 않았는데, 출산 후 지원을 받고 싶어요. 어디로 문의해야 하나요?> hit!
# question <조산이나 저체중으로 태어난 아기가 병원 치료를 받을 때 부모님의 부담금 비율은 어떻게 되나요?> hit!
# question <만 1세 된 아이를 어린이집에 보내지 않고 가정에서 양육할 때 부모가 받을 수 있는 현금 지원은 어떻게 되나요?> hit!
# question <저소득층 가정에 아이가 있는데 기저귀 구입비용 지원을 받고 싶어요. 어디에서 어떻게 지원을 받을 수 있나요?> hit!
# question <아이를 키우는 고등학생 부모인데 지원금 신청은 어디서 해야 하나요?> hit!
# question <제가 밤늦게까지 일을 하는데, 아이를 늦은 시간까지 어린이집에 맡길 수 있을까요?> hit!
# question <열 살짜리 아이가 입원을 해서 병원비를 내야 하는데, 어떤 부분에 대해 지원을 받을 수 있나요?> hit!
# question <제가 운영 중인 청소년 단체의 활동을 확장하고자 하는데, 지원 받을 수 있는 기관을 알려주세요.> hit!
# question <제가 대학교 학부 철학과 1학년인데 장학금을 신청할 수 있나요?> hit!
# question <만 19세인데 학교를 다니지 않아요. 건강검진을 받을 수 있나요?> hit!
# question <위기상황에 처한 청소년이 안전의 위협을 받을때 어디로 연락해야할까요?> hit!
# question <아이가 집을 나간 후로 연락이 안 되는데, 어떤 기관에 도움을 요청해야 하나요?> hit!
# question <대체복무요원으로 일하고 있는데 가정에 긴급한 경제적 문제가 생겼어요. 이럴 때 병역을 감면받을 수 있나요?> hit!
# question <대학생인데, 지금 당장 학비를 마련할 수 없어요. 나중에 직업을 가진 뒤에 돈을 갚을 수 있는 대출이 있다면 알려주세요.> hit!
# question <저는 미술에 재능이 있는 학생입니다. 장학금 지원을 받고 싶은데 어떻게 해야 하죠?> hit!
# question <아이가 암 진단을 받았는데, 의료비 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건강보험 가입자가 중증치매로 인정받을 경우 어떤 혜택을 받을 수 있나요?> hit!
# question <도박 중독으로 고민하는 친구에게 어떻게 도움을 줄 수 있을까요?> hit!
# question <제 어머님이 최근 노인장기요양보험 수급자가 되셨는데요, 어느 정도의 소득 수준이면 본인부담금을 줄일 수 있나요?> hit!
# question <사랑하는 사람이 자살 위험 징후를 보이고 있는데, 어떻게 도움을 줄 수 있을까요?> hit!
# question <곧 있을 퇴직 후 생활에 대비하여 금융상품을 알아보고 싶은데 어디서 정보를 얻을 수 있을까요?> hit!
# question <노인 분들이 문화생활을 즐길 수 있는 공간으로, 어떤 시설이 있는지 궁금해요.> hit!
# question <퇴직 후 급하게 돈이 필요해진 경우, 연금을 받고 있다면 어떠한 정부 지원 프로그램에 참여할 수 있을까요?> hit!
# question <58세이고 7억짜리 집이 있는데, 이 집으로 연금을 받고 싶어. 어떤 제도를 이용할 수 있을까?> hit!
# question <65세 이상인데 치아가 몇 개 빠진 경우에도 임플란트 지원을 받을 수 있나요?> hit!
# question <노년층의 사회 참여를 위한 프로그램에 참여하고 싶어요. 어디에서 신청할 수 있나요?> hit!
# question <제 아이는 청각 장애가 있어 특별한 교육이 필요한데, 특수학급에 참여하려면 어떤 준비를 해야 할까요?> hit!
# question <대학 캠퍼스 안에서 장애 학생을 위한 편의를 제공받고 싶어요. 누구에게 연락해야 하나요?> hit!
# question <현재 자폐 스펙트럼을 가진 4살짜리 아이의 엄마인데요, 상담을 위해 필요한 서류는 무엇인가요?> hit!
# question <우리 회사는 지난달에 중증장애인 2명을 채용했어요. 작업지도에 조언을 해줄 전문 작업지도원도 고용했는데, 국가로부터 어떤 도움을 받을 수 있나요?> hit!
# question <주택을 소유하지 않은 장애인 가구원을 위한 특별공급 주택이 있다고 들었어요. 자격 요건에는 어떤 것들이 있나요?> hit!
# question <신체 장애를 가진 아이의 신체 기능을 회복하기 위한 스포츠 활동은 어디에서 지원받을 수 있나요?> hit!
# question <우리 아버지가 전쟁에 참가하셨고 지금 심리적 방황을 겪고 계셔요. 어디에서 도움을 요청할 수 있을까요?> hit!
# question <저희 할머니께서 독립운동을 하신 유공자셨는데, 혹시 저도 지원을 받을 수 있나요?> hit!
# question <태풍으로 인해 큰 피해를 입었습니다. 정부로부터 보상을 받으려면 어떤 절차를 거쳐야 하나요?> hit!
# question <10년 복무 후 전역한 군인 출신인데, 독립적으로 사업을 시작했습니다. 이 경우 받을 수 있는 지원금이 있나요?> hit!
# question <회사가 경영난으로 인해 문을 닫게 되면서 경제적으로 어려움을 겪고 있어요. 정부 지원금을 어떻게 신청할 수 있나요?> hit!
# question <신용이 낮아서 대출을 받기 어려운데, 저에게 맞는 대출 서비스가 있나요? 어디에 상담을 요청해야 하나요?> hit!
# question <작은 가게를 운영하는데, 자금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건물 임대 관련해서 갈등을 겪고 있어요. 어디로 문의해야 하나요?> hit!
# question <세금 문제를 무료로 상담해 줄 수 있는 곳을 알려주세요.> hit!
# question <혼자 사는 사람들을 위한 친목 모임이나 네트워크 지원이 있는지 궁금해요.> hit!
# question <나는 어업에 종사하고 있고, 앞으로 몇 년간의 수입을 안정적으로 모으고 싶어요. 이런 계획에 맞는 금융 서비스가 있을까요?> hit!
# question <섬에 살아서 배를 자주 이용해야 하는데, 요금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <북한에서 온 내 친구가 대학교 교육비를 지원받고 싶어하는데 어떻게 신청할 수 있나요?> hit!
# question <내 외국인 친구가 건강 문제로 병원을 찾아야 하는 상황인데, 어떤 기관에서 정보를 얻을 수 있나요?> hit!
# question <아빠 없이 아이를 키우고 있는데, 양육비 지원은 어떻게 신청하나요?> hit!
# 60.0
# ================================================================================
#
# with document set <Team B>: text-embedding-ada-002-b, 928, with k=10
# question <가스 안전장치를 설치하고자 하는데 정부 지원은 어떻게 받을 수 있나요?> hit!
# question <제가 간병인을 집으로 부를 수 있게 해주는 서비스는 어디에서 신청할 수 있나요?> hit!
# question <우리 집이 최근 화재로 인해 살 곳을 잃었어요. 긴급하게 지원받을 수 있는 방법이 있을까요?> hit!
# question <저희 어머니가 사시는 임대 아파트가 오래되어 수리가 필요한데, 이런 상황에서 도움받을 수 있는 방법이 있나요?> hit!
# question <아이가 축구학원에 다니고 싶어 하는데, 우리는 기초생활수급 가정이에요. 지원받을 수 있는 방법이 있나요?> hit!
# question <저희 집 벽이 슬레이트인데, 환경적으로 문제가 있어서 갈아내고 싶어요. 이런 경우 어떤 도움을 받을 수 있나요?> hit!
# question <집안의 낡은 전구를 에너지 효율이 좋은 램프로 교체하고 싶어요. 지원을 받으려면 어디로 연락해야 하나요?> hit!
# question <최근 직장을 그만두었는데, 건강보험을 계속해서 유지하고 싶어요. 어떤 제도를 활용할 수 있을까요?> hit!
# question <제가 듣고 있는 일반고 직업교육 과정이 6개월 이상인데, 졸업 후 중견기업에 취업하면 돈을 받을 수 있나요?> hit!
# question <고용보험에 18개월간 가입했지만, 총 근무일수가 180일이 안 되는데 실업급여를 신청할 수 있나요?> hit!
# question <제가 회사와 학교를 병행하며 배울 수 있는 제도에 대해 알아보고 싶어요. 어느 기관에 연락해야 하나요?> hit!
# question <나는 40대 중반에 창업을 계획하고 있어요. 창업 지원과 관련하여 어디에 문의해야 하나요?> hit!
# question <AI나 빅데이터 기술을 배워 직업 훈련을 받으려고 하는데, 어떤 과정들이 제공되나요?> hit!
# question <청년을 채용한 후, 6개월이 지나지 않았는데, 장려금 신청이 가능한가요?> hit!
# question <범죄 경력이 있는 20살 청년이 취업을 희망할 때 이용할 수 있는 프로그램은 무엇인가요?> hit!
# question <졸업 직전인 직업계고 3학년 학생으로서 현장실습에 참여할 예정인데, 어떤 추가적인 혜택을 기대할 수 있나요?> hit!
# question <제가 고용보험에 가입하지 않았는데, 출산 후 지원을 받고 싶어요. 어디로 문의해야 하나요?> hit!
# question <임신 중에 어떤 예방접종을 해야 하는지 알고 싶습니다. 정보를 어디서 찾을 수 있나요?> hit!
# question <조산이나 저체중으로 태어난 아기가 병원 치료를 받을 때 부모님의 부담금 비율은 어떻게 되나요?> hit!
# question <만 1세 된 아이를 어린이집에 보내지 않고 가정에서 양육할 때 부모가 받을 수 있는 현금 지원은 어떻게 되나요?> hit!
# question <열 살짜리 아이가 입원을 해서 병원비를 내야 하는데, 어떤 부분에 대해 지원을 받을 수 있나요?> hit!
# question <제가 운영 중인 청소년 단체의 활동을 확장하고자 하는데, 지원 받을 수 있는 기관을 알려주세요.> hit!
# question <제가 대학교 학부 철학과 1학년인데 장학금을 신청할 수 있나요?> hit!
# question <만 19세인데 학교를 다니지 않아요. 건강검진을 받을 수 있나요?> hit!
# question <위기상황에 처한 청소년이 안전의 위협을 받을때 어디로 연락해야할까요?> hit!
# question <대학생인데, 지금 당장 학비를 마련할 수 없어요. 나중에 직업을 가진 뒤에 돈을 갚을 수 있는 대출이 있다면 알려주세요.> hit!
# question <아이가 암 진단을 받았는데, 의료비 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건강보험 가입자가 중증치매로 인정받을 경우 어떤 혜택을 받을 수 있나요?> hit!
# question <도박 중독으로 고민하는 친구에게 어떻게 도움을 줄 수 있을까요?> hit!
# question <제 어머님이 최근 노인장기요양보험 수급자가 되셨는데요, 어느 정도의 소득 수준이면 본인부담금을 줄일 수 있나요?> hit!
# question <사랑하는 사람이 자살 위험 징후를 보이고 있는데, 어떻게 도움을 줄 수 있을까요?> hit!
# question <노인 분들이 문화생활을 즐길 수 있는 공간으로, 어떤 시설이 있는지 궁금해요.> hit!
# question <58세이고 7억짜리 집이 있는데, 이 집으로 연금을 받고 싶어. 어떤 제도를 이용할 수 있을까?> hit!
# question <65세 이상인데 치아가 몇 개 빠진 경우에도 임플란트 지원을 받을 수 있나요?> hit!
# question <노년층의 사회 참여를 위한 프로그램에 참여하고 싶어요. 어디에서 신청할 수 있나요?> hit!
# question <제 아이는 청각 장애가 있어 특별한 교육이 필요한데, 특수학급에 참여하려면 어떤 준비를 해야 할까요?> hit!
# question <대학 캠퍼스 안에서 장애 학생을 위한 편의를 제공받고 싶어요. 누구에게 연락해야 하나요?> hit!
# question <현재 자폐 스펙트럼을 가진 4살짜리 아이의 엄마인데요, 상담을 위해 필요한 서류는 무엇인가요?> hit!
# question <여자 장애인을 위한 청소 도움을 요청하려면 어떻게 해야 하나요?> hit!
# question <우리 회사는 지난달에 중증장애인 2명을 채용했어요. 작업지도에 조언을 해줄 전문 작업지도원도 고용했는데, 국가로부터 어떤 도움을 받을 수 있나요?> hit!
# question <주택을 소유하지 않은 장애인 가구원을 위한 특별공급 주택이 있다고 들었어요. 자격 요건에는 어떤 것들이 있나요?> hit!
# question <신체 장애를 가진 아이의 신체 기능을 회복하기 위한 스포츠 활동은 어디에서 지원받을 수 있나요?> hit!
# question <우리 아버지가 전쟁에 참가하셨고 지금 심리적 방황을 겪고 계셔요. 어디에서 도움을 요청할 수 있을까요?> hit!
# question <태풍으로 인해 큰 피해를 입었습니다. 정부로부터 보상을 받으려면 어떤 절차를 거쳐야 하나요?> hit!
# question <10년 복무 후 전역한 군인 출신인데, 독립적으로 사업을 시작했습니다. 이 경우 받을 수 있는 지원금이 있나요?> hit!
# question <저희 아버지께서 국가유공상이자로 6급 판정을 받으셨어요. 시내버스를 비롯한 대중교통을 이용할 때 혜택이 있나요?> hit!
# question <신용이 낮아서 대출을 받기 어려운데, 저에게 맞는 대출 서비스가 있나요? 어디에 상담을 요청해야 하나요?> hit!
# question <작은 가게를 운영하는데, 자금 지원을 받으려면 어떻게 해야 하나요?> hit!
# question <건물 임대 관련해서 갈등을 겪고 있어요. 어디로 문의해야 하나요?> hit!
# question <혼자 사는 사람들을 위한 친목 모임이나 네트워크 지원이 있는지 궁금해요.> hit!
# question <북한에서 온 내 친구가 대학교 교육비를 지원받고 싶어하는데 어떻게 신청할 수 있나요?> hit!
# question <농사일이 바빠서 혼자서 다 하기 힘든데, 정부에서 도와줄 수 있는 프로그램이 있나요?> hit!
# question <아빠 없이 아이를 키우고 있는데, 양육비 지원은 어떻게 신청하나요?> hit!
# 50.476190476190474
# ================================================================================
